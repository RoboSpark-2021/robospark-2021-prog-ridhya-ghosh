# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Asus/Downloads/data.csv")

# %%
df
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
df.drop(labels={'name','passenger_id','cabin','ticket','sex','age',},axis=1,inplace=True)

# %%
df
# Out:
#      pclass  sibsp  parch     fare embarked boat   body  \
# 0         3      0      0   7.7333        Q   13    NaN
# 1         3      0      0   8.6625        S  NaN    NaN
# 2         3      1      1  24.1500        S  NaN    NaN
# 3         2      1      3  23.0000        S    4    NaN
# 4         2      0      0  13.0000        S  NaN    NaN
# ..      ...    ...    ...      ...      ...  ...    ...
# 845       1      0      0  50.0000        S  NaN    NaN
# 846       1      0      0  29.7000        C  NaN  258.0
# 847       2      1      0  26.0000        S   12    NaN
# 848       3      1      1  13.7750        S  NaN    NaN
# 849       2      0      0  13.0000        S  NaN   19.0
#
#                     home.dest  survived
# 0                         NaN         1
# 1                     Croatia         0
# 2                         NaN         0
# 3        Cornwall / Akron, OH         1
# 4    Barre, Co Washington, VT         0
# ..                        ...       ...
# ...

# %%
df['embarked'].unique()
# Out:
# array(['Q', 'S', 'C', nan], dtype=object)

# %%
df['boat'].unique()
# Out:
# array(['13', nan, '4', '10', 'C', '8', '7', '16', '6', 'A', '15', '9',
#        '14', '3', '11', '12', '2', '5 7', '5 9', 'B', '5', 'D', '1',
#        'C D', '13 15', '13 15 B', '15 16'], dtype=object)

# %%
df.isnull().sum()
# Out:
# pclass         0
# sibsp          0
# parch          0
# fare           1
# embarked       1
# boat         542
# body         777
# home.dest    386
# survived       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = ['embarked','home.dest','boat']
for i in l:
    le = LabelEncoder()
    le.fit(df[i])
    df[i]=le.transform(df[i])

# %%
df
# Out:
#      pclass  sibsp  parch     fare  embarked  boat   body  home.dest  survived
# 0         3      0      0   7.7333         1     4    NaN        272         1
# 1         3      0      0   8.6625         2    26    NaN         56         0
# 2         3      1      1  24.1500         2    26    NaN        272         0
# 3         2      1      3  23.0000         2    13    NaN         52         1
# 4         2      0      0  13.0000         2    26    NaN         11         0
# ..      ...    ...    ...      ...       ...   ...    ...        ...       ...
# 845       1      0      0  50.0000         2    26    NaN        139         0
# 846       1      0      0  29.7000         0    26  258.0         35         0
# 847       2      1      0  26.0000         2     3    NaN        166         1
# 848       3      1      1  13.7750         2    26    NaN        272         0
# 849       2      0      0  13.0000         2    26   19.0         27         0
#
# [850 rows x 9 columns]

# %%
col_null = ['embarked','fare','body','boat'] 

med = []


for i in col_null: 
    med.append(df[i].median())  

k = 0 

for i in col_null:
    df[i].fillna(med[k] , inplace = True)   
    k = k + 1

# %%
df
# Out:
#      pclass  sibsp  parch     fare  embarked  boat   body  home.dest  survived
# 0         3      0      0   7.7333         1     4  166.0        272         1
# 1         3      0      0   8.6625         2    26  166.0         56         0
# 2         3      1      1  24.1500         2    26  166.0        272         0
# 3         2      1      3  23.0000         2    13  166.0         52         1
# 4         2      0      0  13.0000         2    26  166.0         11         0
# ..      ...    ...    ...      ...       ...   ...    ...        ...       ...
# 845       1      0      0  50.0000         2    26  166.0        139         0
# 846       1      0      0  29.7000         0    26  258.0         35         0
# 847       2      1      0  26.0000         2     3  166.0        166         1
# 848       3      1      1  13.7750         2    26  166.0        272         0
# 849       2      0      0  13.0000         2    26   19.0         27         0
#
# [850 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# pclass       0
# sibsp        0
# parch        0
# fare         0
# embarked     0
# boat         0
# body         0
# home.dest    0
# survived     0
# dtype: int64

# %%
col_norm = ['fare']
Max = [] 

for i in col_norm : 
    Max.append(df[i].max())

k = 0 
 
for i in col_norm : 
    df[i] = df[i]/Max[k]
    k = k + 1

# %%
x = df.drop(['survived'], axis=1)
y = df[['survived']]

# %%
x
# Out:
#      pclass  sibsp  parch      fare  embarked  boat   body  home.dest
# 0         3      0      0  0.015094         1     4  166.0        272
# 1         3      0      0  0.016908         2    26  166.0         56
# 2         3      1      1  0.047138         2    26  166.0        272
# 3         2      1      3  0.044893         2    13  166.0         52
# 4         2      0      0  0.025374         2    26  166.0         11
# ..      ...    ...    ...       ...       ...   ...    ...        ...
# 845       1      0      0  0.097594         2    26  166.0        139
# 846       1      0      0  0.057971         0    26  258.0         35
# 847       2      1      0  0.050749         2     3  166.0        166
# 848       3      1      1  0.026887         2    26  166.0        272
# 849       2      0      0  0.025374         2    26   19.0         27
#
# [850 rows x 8 columns]

# %%
y
# Out:
#      survived
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# ..        ...
# 845         0
# 846         0
# 847         1
# 848         0
# 849         0
#
# [850 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
d = DecisionTreeClassifier()
d.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
acc_score = d.score(X_test,y_test)

# %%
print("Accuracy of my model is: ",acc_score*100)
# Out:
# Accuracy of my model is:  95.88235294117648
